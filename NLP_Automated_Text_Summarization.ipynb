# %% [markdown]
# <a href="https://colab.research.google.com/github/Manish1176/Machine-Learning-Project/blob/main/NLP_Automated_Text_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="""New Zealand, island country in the South Pacific Ocean, the southwesternmost part of Polynesia. New Zealand is a remote land—one of the last sizable territories suitable for habitation to be populated and settled—and lies more than 1,000 miles (1,600 km) southeast of Australia, its nearest neighbour. The country comprises two main islands—the North and the South Island—and a number of small islands, some of them hundreds of miles from the main group. The capital city is Wellington and the largest urban area Auckland; both are located on the North Island. New Zealand administers the South Pacific island group of Tokelau and claims a section of the Antarctic continent. Niue and the Cook Islands are self-governing states in free association with New Zealand.New Zealand is a land of great contrasts and diversity. Active volcanoes, spectacular caves, deep glacier lakes, verdant valleys, dazzling fjords, long sandy beaches, and the spectacular snowcapped peaks of the Southern Alps/Kā Tiritiri o te Moana on the South Island—all contribute to New Zealand’s scenic beauty. New Zealand also has a unique array of vegetation and animal life, much of which developed during the country’s prolonged isolation. It is the sole home, for example, of the long-beaked, flightless kiwi, the ubiquitous nickname for New Zealanders.To counter China, NATO and its Asian partners are moving closer under US leadership.New Zealand was the largest country in Polynesia when it was annexed by Great Britain in 1840. Thereafter it was successively a crown colony, a self-governing colony (1856), and a dominion (1907). By the 1920s it controlled almost all of its internal and external policies, although it did not become fully independent until 1947, when it adopted the Statute of Westminster. It is a member of the Commonwealth.The ascent of Mount Everest by New Zealander Sir Edmund Hillary with Sherpa Tenzing Norgay in 1953 was one of the defining moments of the 20th century. “In some ways,” Hillary suggested, “I believe I epitomise the average New Zealander: I have modest abilities, I combine these with a good deal of determination, and I rather like to succeed."""

# %%
len(text)
# Out:
# 2163

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.8.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
tokens=[]
stopwords = list(STOP_WORDS)
allowed_pos = ['ADJ','PROPN','VERB','NOUN']
for token in doc:
    if token.text in stopwords or token.text in punctuation:
        continue
    if token.pos_ in allowed_pos:
        tokens.append(token.text)

# %%
tokens
# Out:
# ['New',
#  'Zealand',
#  'island',
#  'country',
#  'South',
#  'Pacific',
#  'Ocean',
#  'southwesternmost',
#  'Polynesia',
#  'New',
#  'Zealand',
#  'remote',
#  'land',
#  'sizable',
#  'territories',
#  'suitable',
#  'habitation',
#  'populated',
#  'settled',
#  'lies',
#  'miles',
#  'km',
#  'southeast',
#  'Australia',
#  'nearest',
#  'neighbour',
#  'country',
#  'comprises',
#  'main',
#  'islands',
#  'North',
#  'South',
#  'Island',
#  'number',
#  'small',
#  'islands',
#  'hundreds',
#  'miles',
#  'main',
#  'group',
#  'capital',
#  'city',
#  'Wellington',
#  'largest',
#  'urban',
#  'area',
#  'Auckland',
#  'located',
#  'North',
#  'Island',
#  'New',
#  'Zealand',
#  'administers',
#  'South',
#  'Pacific',
#  'island',
#  'group',
#  'Tokelau',
#  'claims',
#  'section',
#  'Antarctic',
#  'continent',
#  'Niue',
#  'Cook',
#  'Islands',
#  'self',
#  'governing',
#  'states',
#  'free',
#  'association',
#  'New',
#  'Zealand',
#  'New',
#  'Zealand',
#  'land',
#  'great',
#  'contrasts',
#  'diversity',
#  'Active',
#  'volcanoes',
#  'spectacular',
#  'caves',
#  'deep',
#  'glacier',
#  'lakes',
#  'verdant',
#  'valleys',
#  'dazzling',
#  'fjords',
#  'long',
#  'sandy',
#  'beaches',
#  'spectacular',
#  'snowcapped',
#  'peaks',
#  'Southern',
#  'Alps',
#  'Kā',
#  'Tiritiri',
#  'o',
#  'Moana',
#  'South',
#  'Island',
#  'contribute',
#  'New',
#  'Zealand',
#  'scenic',
#  'beauty',
#  'New',
#  'Zealand',
#  'unique',
#  'array',
#  'vegetation',
#  'animal',
#  'life',
#  'developed',
#  'country',
#  'prolonged',
#  'isolation',
#  'sole',
#  'home',
#  'example',
#  'beaked',
#  'flightless',
#  'kiwi',
#  'ubiquitous',
#  'nickname',
#  'New',
#  'Zealanders',
#  'counter',
#  'China',
#  'NATO',
#  'Asian',
#  'partners',
#  'moving',
#  'US',
#  'leadership',
#  'New',
#  'Zealand',
#  'largest',
#  'country',
#  'Polynesia',
#  'annexed',
#  'Great',
#  'Britain',
#  'crown',
#  'colony',
#  'self',
#  'governing',
#  'colony',
#  'dominion',
#  '1920s',
#  'controlled',
#  'internal',
#  'external',
#  'policies',
#  'independent',
#  'adopted',
#  'Statute',
#  'Westminster',
#  'member',
#  'Commonwealth',
#  'ascent',
#  'Mount',
#  'Everest',
#  'New',
#  'Zealander',
#  'Sir',
#  'Edmund',
#  'Hillary',
#  'Sherpa',
#  'Tenzing',
#  'Norgay',
#  'defining',
#  'moments',
#  '20th',
#  'century',
#  'ways',
#  'Hillary',
#  'suggested',
#  'believe',
#  'epitomise',
#  'average',
#  'New',
#  'Zealander',
#  'modest',
#  'abilities',
#  'combine',
#  'good',
#  'deal',
#  'determination',
#  'like',
#  'succeed']

# %%
from collections import Counter

# %%
word_freq = Counter(tokens)

# %%
word_freq
# Out:
# Counter({'New': 11,
#          'Zealand': 8,
#          'island': 2,
#          'country': 4,
#          'South': 4,
#          'Pacific': 2,
#          'Ocean': 1,
#          'southwesternmost': 1,
#          'Polynesia': 2,
#          'remote': 1,
#          'land': 2,
#          'sizable': 1,
#          'territories': 1,
#          'suitable': 1,
#          'habitation': 1,
#          'populated': 1,
#          'settled': 1,
#          'lies': 1,
#          'miles': 2,
#          'km': 1,
#          'southeast': 1,
#          'Australia': 1,
#          'nearest': 1,
#          'neighbour': 1,
#          'comprises': 1,
#          'main': 2,
#          'islands': 2,
#          'North': 2,
#          'Island': 3,
#          'number': 1,
#          'small': 1,
#          'hundreds': 1,
#          'group': 2,
#          'capital': 1,
#          'city': 1,
#          'Wellington': 1,
#          'largest': 2,
#          'urban': 1,
#          'area': 1,
#          'Auckland': 1,
#          'located': 1,
#          'administers': 1,
#          'Tokelau': 1,
#          'claims': 1,
#          'section': 1,
#          'Antarctic': 1,
#          'continent': 1,
#          'Niue': 1,
#          'Cook': 1,
#          'Islands': 1,
#          'self': 2,
#          'governing': 2,
#          'states': 1,
#          'free': 1,
#          'association': 1,
#          'great': 1,
#          'contrasts': 1,
#          'diversity': 1,
#          'Active': 1,
#          'volcanoes': 1,
#          'spectacular': 2,
#          'caves': 1,
#          'deep': 1,
#          'glacier': 1,
#          'lakes': 1,
#          'verdant': 1,
#          'valleys': 1,
#          'dazzling': 1,
#          'fjords': 1,
#          'long': 1,
#          'sandy': 1,
#          'beaches': 1,
#          'snowcapped': 1,
#          'peaks': 1,
#          'Southern': 1,
#          'Alps': 1,
#          'Kā': 1,
#          'Tiritiri': 1,
#          'o': 1,
#          'Moana': 1,
#          'contribute': 1,
#          'scenic': 1,
#          'beauty': 1,
#          'unique': 1,
#          'array': 1,
#          'vegetation': 1,
#          'animal': 1,
#          'life': 1,
#          'developed': 1,
#          'prolonged': 1,
#          'isolation': 1,
#          'sole': 1,
#          'home': 1,
#          'example': 1,
#          'beaked': 1,
#          'flightless': 1,
#          'kiwi': 1,
#          'ubiquitous': 1,
#          'nickname': 1,
#          'Zealanders': 1,
#          'counter': 1,
#          'China': 1,
#          'NATO': 1,
#          'Asian': 1,
#          'partners': 1,
#          'moving': 1,
#          'US': 1,
#          'leadership': 1,
#          'annexed': 1,
#          'Great': 1,
#          'Britain': 1,
#          'crown': 1,
#          'colony': 2,
#          'dominion': 1,
#          '1920s': 1,
#          'controlled': 1,
#          'internal': 1,
#          'external': 1,
#          'policies': 1,
#          'independent': 1,
#          'adopted': 1,
#          'Statute': 1,
#          'Westminster': 1,
#          'member': 1,
#          'Commonwealth': 1,
#          'ascent': 1,
#          'Mount': 1,
#          'Everest': 1,
#          'Zealander': 2,
#          'Sir': 1,
#          'Edmund': 1,
#          'Hillary': 2,
#          'Sherpa': 1,
#          'Tenzing': 1,
#          'Norgay': 1,
#          'defining': 1,
#          'moments': 1,
#          '20th': 1,
#          'century': 1,
#          'ways': 1,
#          'suggested': 1,
#          'believe': 1,
#          'epitomise': 1,
#          'average': 1,
#          'modest': 1,
#          'abilities': 1,
#          'combine': 1,
#          'good': 1,
#          'deal': 1,
#          'determination': 1,
#          'like': 1,
#          'succeed': 1})

# %%
max_freq = max(word_freq.values())

# %%
max_freq
# Out:
# 11

# %%
for word in word_freq.keys():
    word_freq[word] = word_freq[word]/max_freq

# %%
word_freq
# Out:
# Counter({'New': 1.0,
#          'Zealand': 0.7272727272727273,
#          'island': 0.18181818181818182,
#          'country': 0.36363636363636365,
#          'South': 0.36363636363636365,
#          'Pacific': 0.18181818181818182,
#          'Ocean': 0.09090909090909091,
#          'southwesternmost': 0.09090909090909091,
#          'Polynesia': 0.18181818181818182,
#          'remote': 0.09090909090909091,
#          'land': 0.18181818181818182,
#          'sizable': 0.09090909090909091,
#          'territories': 0.09090909090909091,
#          'suitable': 0.09090909090909091,
#          'habitation': 0.09090909090909091,
#          'populated': 0.09090909090909091,
#          'settled': 0.09090909090909091,
#          'lies': 0.09090909090909091,
#          'miles': 0.18181818181818182,
#          'km': 0.09090909090909091,
#          'southeast': 0.09090909090909091,
#          'Australia': 0.09090909090909091,
#          'nearest': 0.09090909090909091,
#          'neighbour': 0.09090909090909091,
#          'comprises': 0.09090909090909091,
#          'main': 0.18181818181818182,
#          'islands': 0.18181818181818182,
#          'North': 0.18181818181818182,
#          'Island': 0.2727272727272727,
#          'number': 0.09090909090909091,
#          'small': 0.09090909090909091,
#          'hundreds': 0.09090909090909091,
#          'group': 0.18181818181818182,
#          'capital': 0.09090909090909091,
#          'city': 0.09090909090909091,
#          'Wellington': 0.09090909090909091,
#          'largest': 0.18181818181818182,
#          'urban': 0.09090909090909091,
#          'area': 0.09090909090909091,
#          'Auckland': 0.09090909090909091,
#          'located': 0.09090909090909091,
#          'administers': 0.09090909090909091,
#          'Tokelau': 0.09090909090909091,
#          'claims': 0.09090909090909091,
#          'section': 0.09090909090909091,
#          'Antarctic': 0.09090909090909091,
#          'continent': 0.09090909090909091,
#          'Niue': 0.09090909090909091,
#          'Cook': 0.09090909090909091,
#          'Islands': 0.09090909090909091,
#          'self': 0.18181818181818182,
#          'governing': 0.18181818181818182,
#          'states': 0.09090909090909091,
#          'free': 0.09090909090909091,
#          'association': 0.09090909090909091,
#          'great': 0.09090909090909091,
#          'contrasts': 0.09090909090909091,
#          'diversity': 0.09090909090909091,
#          'Active': 0.09090909090909091,
#          'volcanoes': 0.09090909090909091,
#          'spectacular': 0.18181818181818182,
#          'caves': 0.09090909090909091,
#          'deep': 0.09090909090909091,
#          'glacier': 0.09090909090909091,
#          'lakes': 0.09090909090909091,
#          'verdant': 0.09090909090909091,
#          'valleys': 0.09090909090909091,
#          'dazzling': 0.09090909090909091,
#          'fjords': 0.09090909090909091,
#          'long': 0.09090909090909091,
#          'sandy': 0.09090909090909091,
#          'beaches': 0.09090909090909091,
#          'snowcapped': 0.09090909090909091,
#          'peaks': 0.09090909090909091,
#          'Southern': 0.09090909090909091,
#          'Alps': 0.09090909090909091,
#          'Kā': 0.09090909090909091,
#          'Tiritiri': 0.09090909090909091,
#          'o': 0.09090909090909091,
#          'Moana': 0.09090909090909091,
#          'contribute': 0.09090909090909091,
#          'scenic': 0.09090909090909091,
#          'beauty': 0.09090909090909091,
#          'unique': 0.09090909090909091,
#          'array': 0.09090909090909091,
#          'vegetation': 0.09090909090909091,
#          'animal': 0.09090909090909091,
#          'life': 0.09090909090909091,
#          'developed': 0.09090909090909091,
#          'prolonged': 0.09090909090909091,
#          'isolation': 0.09090909090909091,
#          'sole': 0.09090909090909091,
#          'home': 0.09090909090909091,
#          'example': 0.09090909090909091,
#          'beaked': 0.09090909090909091,
#          'flightless': 0.09090909090909091,
#          'kiwi': 0.09090909090909091,
#          'ubiquitous': 0.09090909090909091,
#          'nickname': 0.09090909090909091,
#          'Zealanders': 0.09090909090909091,
#          'counter': 0.09090909090909091,
#          'China': 0.09090909090909091,
#          'NATO': 0.09090909090909091,
#          'Asian': 0.09090909090909091,
#          'partners': 0.09090909090909091,
#          'moving': 0.09090909090909091,
#          'US': 0.09090909090909091,
#          'leadership': 0.09090909090909091,
#          'annexed': 0.09090909090909091,
#          'Great': 0.09090909090909091,
#          'Britain': 0.09090909090909091,
#          'crown': 0.09090909090909091,
#          'colony': 0.18181818181818182,
#          'dominion': 0.09090909090909091,
#          '1920s': 0.09090909090909091,
#          'controlled': 0.09090909090909091,
#          'internal': 0.09090909090909091,
#          'external': 0.09090909090909091,
#          'policies': 0.09090909090909091,
#          'independent': 0.09090909090909091,
#          'adopted': 0.09090909090909091,
#          'Statute': 0.09090909090909091,
#          'Westminster': 0.09090909090909091,
#          'member': 0.09090909090909091,
#          'Commonwealth': 0.09090909090909091,
#          'ascent': 0.09090909090909091,
#          'Mount': 0.09090909090909091,
#          'Everest': 0.09090909090909091,
#          'Zealander': 0.18181818181818182,
#          'Sir': 0.09090909090909091,
#          'Edmund': 0.09090909090909091,
#          'Hillary': 0.18181818181818182,
#          'Sherpa': 0.09090909090909091,
#          'Tenzing': 0.09090909090909091,
#          'Norgay': 0.09090909090909091,
#          'defining': 0.09090909090909091,
#          'moments': 0.09090909090909091,
#          '20th': 0.09090909090909091,
#          'century': 0.09090909090909091,
#          'ways': 0.09090909090909091,
#          'suggested': 0.09090909090909091,
#          'believe': 0.09090909090909091,
#          'epitomise': 0.09090909090909091,
#          'average': 0.09090909090909091,
#          'modest': 0.09090909090909091,
#          'abilities': 0.09090909090909091,
#          'combine': 0.09090909090909091,
#          'good': 0.09090909090909091,
#          'deal': 0.09090909090909091,
#          'determination': 0.09090909090909091,
#          'like': 0.09090909090909091,
#          'succeed': 0.09090909090909091})

# %%
sent_token = [sent.text for sent in doc.sents]

# %%
sent_token
# Out:
# ['New Zealand, island country in the South Pacific Ocean, the southwesternmost part of Polynesia.',
#  'New Zealand is a remote land—one of the last sizable territories suitable for habitation to be populated and settled—and lies more than 1,000 miles (1,600 km) southeast of Australia, its nearest neighbour.',
#  'The country comprises two main islands—the North and the South Island—and a number of small islands, some of them hundreds of miles from the main group.',
#  'The capital city is Wellington and the largest urban area Auckland; both are located on the North Island.',
#  'New Zealand administers the South Pacific island group of Tokelau and claims a section of the Antarctic continent.',
#  'Niue and the Cook Islands are self-governing states in free association with New Zealand.',
#  'New Zealand is a land of great contrasts and diversity.',
#  'Active volcanoes, spectacular caves, deep glacier lakes, verdant valleys, dazzling fjords, long sandy beaches, and the spectacular snowcapped peaks of the Southern Alps/Kā Tiritiri o te Moana on the South Island—all contribute to New Zealand’s scenic beauty.',
#  'New Zealand also has a unique array of vegetation and animal life, much of which developed during the country’s prolonged isolation.',
#  'It is the sole home, for example, of the long-beaked, flightless kiwi, the ubiquitous nickname for New Zealanders.',
#  'To counter China, NATO and its Asian partners are moving closer under US leadership.',
#  'New Zealand was the largest country in Polynesia when it was annexed by Great Britain in 1840.',
#  'Thereafter it was successively a crown colony, a self-governing colony (1856), and a dominion (1907).',
#  'By the 1920s it controlled almost all of its internal and external policies, although it did not become fully independent until 1947, when it adopted the Statute of Westminster.',
#  'It is a member of the Commonwealth.',
#  'The ascent of Mount Everest by New Zealander Sir Edmund Hillary with Sherpa Tenzing Norgay in 1953 was one of the defining moments of the 20th century.',
#  '“In some ways,” Hillary suggested, “I believe I epitomise the average New Zealander: I have modest abilities, I combine these with a good deal of determination, and I rather like to succeed.']

# %%
sent_score = {}
for sent in sent_token:
    for word in sent.split():
        if word.lower() in word_freq.keys():
            if sent not in sent_score.keys():
                sent_score[sent] = word_freq[word]
            else:
                sent_score[sent] +=word_freq[word]
        print(word)
# Out:
# New
# Zealand,
# island
# country
# in
# the
# South
# Pacific
# Ocean,
# the
# southwesternmost
# part
# of
# Polynesia.
# New
# Zealand
# is
# a
# remote
# land—one
# of
# the
# last
# sizable
# territories
# suitable
# for
# habitation
# to
# be
# populated
# and
# settled—and
# lies
# more
# than
# 1,000
# miles
# (1,600
# km)
# southeast
# of
# Australia,
# its
# nearest
# neighbour.
# The
# country
# comprises
# two
# main
# islands—the
# North
# and
# the
# South
# Island—and
# a
# number
# of
# small
# islands,
# some
# of
# them
# hundreds
# of
# miles
# from
# the
# main
# group.
# The
# capital
# city
# is
# Wellington
# and
# the
# largest
# urban
# area
# Auckland;
# both
# are
# located
# on
# the
# North
# Island.
# New
# Zealand
# administers
# the
# South
# Pacific
# island
# group
# of
# Tokelau
# and
# claims
# a
# section
# of
# the
# Antarctic
# continent.
# Niue
# and
# the
# Cook
# Islands
# are
# self-governing
# states
# in
# free
# association
# with
# New
# Zealand.
# New
# Zealand
# is
# a
# land
# of
# great
# contrasts
# and
# diversity.
# Active
# volcanoes,
# spectacular
# caves,
# deep
# glacier
# lakes,
# verdant
# valleys,
# dazzling
# fjords,
# long
# sandy
# beaches,
# and
# the
# spectacular
# snowcapped
# peaks
# of
# the
# Southern
# Alps/Kā
# Tiritiri
# o
# te
# Moana
# on
# the
# South
# Island—all
# contribute
# to
# New
# Zealand’s
# scenic
# beauty.
# New
# Zealand
# also
# has
# a
# unique
# array
# of
# vegetation
# and
# animal
# life,
# much
# of
# which
# developed
# during
# the
# country’s
# prolonged
# isolation.
# It
# is
# the
# sole
# home,
# for
# example,
# of
# the
# long-beaked,
# flightless
# kiwi,
# the
# ubiquitous
# nickname
# for
# New
# Zealanders.
# To
# counter
# China,
# NATO
# and
# its
# Asian
# partners
# are
# moving
# closer
# under
# US
# leadership.
# New
# Zealand
# was
# the
# largest
# country
# in
# Polynesia
# when
# it
# was
# annexed
# by
# Great
# Britain
# in
# 1840.
# Thereafter
# it
# was
# successively
# a
# crown
# colony,
# a
# self-governing
# colony
# (1856),
# and
# a
# dominion
# (1907).
# By
# the
# 1920s
# it
# controlled
# almost
# all
# of
# its
# internal
# and
# external
# policies,
# although
# it
# did
# not
# become
# fully
# independent
# until
# 1947,
# when
# it
# adopted
# the
# Statute
# of
# Westminster.
# It
# is
# a
# member
# of
# the
# Commonwealth.
# The
# ascent
# of
# Mount
# Everest
# by
# New
# Zealander
# Sir
# Edmund
# Hillary
# with
# Sherpa
# Tenzing
# Norgay
# in
# 1953
# was
# one
# of
# the
# defining
# moments
# of
# the
# 20th
# century.
# “In
# some
# ways,”
# Hillary
# suggested,
# “I
# believe
# I
# epitomise
# the
# average
# New
# Zealander:
# I
# have
# modest
# abilities,
# I
# combine
# these
# with
# a
# good
# deal
# of
# determination,
# and
# I
# rather
# like
# to
# succeed.

# %%
sent_score
# Out:
# {'New Zealand, island country in the South Pacific Ocean, the southwesternmost part of Polynesia.': 0.6363636363636364,
#  'New Zealand is a remote land—one of the last sizable territories suitable for habitation to be populated and settled—and lies more than 1,000 miles (1,600 km) southeast of Australia, its nearest neighbour.': 1.0000000000000002,
#  'The country comprises two main islands—the North and the South Island—and a number of small islands, some of them hundreds of miles from the main group.': 1.272727272727273,
#  'The capital city is Wellington and the largest urban area Auckland; both are located on the North Island.': 0.6363636363636365,
#  'New Zealand administers the South Pacific island group of Tokelau and claims a section of the Antarctic continent.': 0.6363636363636364,
#  'Niue and the Cook Islands are self-governing states in free association with New Zealand.': 0.36363636363636365,
#  'New Zealand is a land of great contrasts and diversity.': 0.36363636363636365,
#  'Active volcanoes, spectacular caves, deep glacier lakes, verdant valleys, dazzling fjords, long sandy beaches, and the spectacular snowcapped peaks of the Southern Alps/Kā Tiritiri o te Moana on the South Island—all contribute to New Zealand’s scenic beauty.': 1.3636363636363633,
#  'New Zealand also has a unique array of vegetation and animal life, much of which developed during the country’s prolonged isolation.': 0.5454545454545455,
#  'It is the sole home, for example, of the long-beaked, flightless kiwi, the ubiquitous nickname for New Zealanders.': 0.36363636363636365,
#  'To counter China, NATO and its Asian partners are moving closer under US leadership.': 0.2727272727272727,
#  'New Zealand was the largest country in Polynesia when it was annexed by Great Britain in 1840.': 0.7272727272727273,
#  'Thereafter it was successively a crown colony, a self-governing colony (1856), and a dominion (1907).': 0.36363636363636365,
#  'By the 1920s it controlled almost all of its internal and external policies, although it did not become fully independent until 1947, when it adopted the Statute of Westminster.': 0.5454545454545455,
#  'It is a member of the Commonwealth.': 0.09090909090909091,
#  'The ascent of Mount Everest by New Zealander Sir Edmund Hillary with Sherpa Tenzing Norgay in 1953 was one of the defining moments of the 20th century.': 0.36363636363636365,
#  '“In some ways,” Hillary suggested, “I believe I epitomise the average New Zealander: I have modest abilities, I combine these with a good deal of determination, and I rather like to succeed.': 0.7272727272727274}

# %%
import pandas as pd

# %%
pd.DataFrame(list(sent_score.items()),columns=['Sentence','Score'])
# Out:
#                                              Sentence     Score
# 0   New Zealand, island country in the South Pacif...  0.636364
# 1   New Zealand is a remote land—one of the last s...  1.000000
# 2   The country comprises two main islands—the Nor...  1.272727
# 3   The capital city is Wellington and the largest...  0.636364
# 4   New Zealand administers the South Pacific isla...  0.636364
# 5   Niue and the Cook Islands are self-governing s...  0.363636
# 6   New Zealand is a land of great contrasts and d...  0.363636
# 7   Active volcanoes, spectacular caves, deep glac...  1.363636
# 8   New Zealand also has a unique array of vegetat...  0.545455
# 9   It is the sole home, for example, of the long-...  0.363636
# 10  To counter China, NATO and its Asian partners ...  0.272727
# 11  New Zealand was the largest country in Polynes...  0.727273
# 12  Thereafter it was successively a crown colony,...  0.363636
# 13  By the 1920s it controlled almost all of its i...  0.545455
# 14                It is a member of the Commonwealth.  0.090909
# 15  The ascent of Mount Everest by New Zealander S...  0.363636
# 16  “In some ways,” Hillary suggested, “I believe ...  0.727273

# %%
from heapq import nlargest

# %%
num_sentences =3
n = nlargest(num_sentences,sent_score,key=sent_score.get)

# %%
" ".join(n)
# Out:
# 'Active volcanoes, spectacular caves, deep glacier lakes, verdant valleys, dazzling fjords, long sandy beaches, and the spectacular snowcapped peaks of the Southern Alps/Kā Tiritiri o te Moana on the South Island—all contribute to New Zealand’s scenic beauty. The country comprises two main islands—the North and the South Island—and a number of small islands, some of them hundreds of miles from the main group. New Zealand is a remote land—one of the last sizable territories suitable for habitation to be populated and settled—and lies more than 1,000 miles (1,600 km) southeast of Australia, its nearest neighbour.'

# %%
from transformers import pipeline

# %%
summarizer=pipeline("summarization",model='t5-base',tokenizer='t5-base',framework='pt')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]

# %%
text="""New Zealand, island country in the South Pacific Ocean, the southwesternmost part of Polynesia. New Zealand is a remote land—one of the last sizable territories suitable for habitation to be populated and settled—and lies more than 1,000 miles (1,600 km) southeast of Australia, its nearest neighbour. The country comprises two main islands—the North and the South Island—and a number of small islands, some of them hundreds of miles from the main group. The capital city is Wellington and the largest urban area Auckland; both are located on the North Island. New Zealand administers the South Pacific island group of Tokelau and claims a section of the Antarctic continent. Niue and the Cook Islands are self-governing states in free association with New Zealand.New Zealand is a land of great contrasts and diversity. Active volcanoes, spectacular caves, deep glacier lakes, verdant valleys, dazzling fjords, long sandy beaches, and the spectacular snowcapped peaks of the Southern Alps/Kā Tiritiri o te Moana on the South Island—all contribute to New Zealand’s scenic beauty. New Zealand also has a unique array of vegetation and animal life, much of which developed during the country’s prolonged isolation. It is the sole home, for example, of the long-beaked, flightless kiwi, the ubiquitous nickname for New Zealanders.To counter China, NATO and its Asian partners are moving closer under US leadership.New Zealand was the largest country in Polynesia when it was annexed by Great Britain in 1840. Thereafter it was successively a crown colony, a self-governing colony (1856), and a dominion (1907). By the 1920s it controlled almost all of its internal and external policies, although it did not become fully independent until 1947, when it adopted the Statute of Westminster. It is a member of the Commonwealth.The ascent of Mount Everest by New Zealander Sir Edmund Hillary with Sherpa Tenzing Norgay in 1953 was one of the defining moments of the 20th century. “In some ways,” Hillary suggested, “I believe I epitomise the average New Zealander: I have modest abilities, I combine these with a good deal of determination, and I rather like to succeed."""

# %%
summary = summarizer(text,max_length=100,min_length=10,do_sample=False)

# %%
summary
# Out:
# [{'summary_text': 'New Zealand is one of the last sizable territories suitable for habitation to be populated and settled . the country comprises two main islands—the North and the South Island—and a number of small islands . active volcanoes, spectacular caves, deep glacier lakes, verdant valleys, dazzling fjords, long sandy beaches contribute to the country’s scenic beauty .'}]

# %%
print(summary[0]['summary_text'])
# Out:
# New Zealand is one of the last sizable territories suitable for habitation to be populated and settled . the country comprises two main islands—the North and the South Island—and a number of small islands . active volcanoes, spectacular caves, deep glacier lakes, verdant valleys, dazzling fjords, long sandy beaches contribute to the country’s scenic beauty .
